# %% [markdown]
# <a href="https://colab.research.google.com/github/Maneerat-Aechaiyaphum/PytonDataViz2026/blob/main/HW1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #มณีรัตน์ เอชัยภูมิ

# %%
print('66302027-0')
# Out:
# 66302027-0
